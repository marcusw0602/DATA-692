# %%
# Import libraries
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the 2017-2018 school year file "MERGED2017_18_PP.csv" 
# Don't include all columns - too many and take up computer resources (computeing power and memory)
# Only load the following 10 columns should be loaded:
# UNITID: 
# OPEID:              
# OPEID6:            
# INSTNM:          
# CITY:                      
# ZIP:               
# ADM_RATE:           
# UGDS:              
# TUITIONFEE_IN:
df = pd.read_csv("MERGED2017_18_PP.csv", skipinitialspace = True, usecols = ['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN'])

# %%
# <3>
# Load the scorecard file Most-Recent-Cohorts-Scorecard-Elements.csv from the link:
# https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-Scorecard-Elements.csv
# This file has thre median earnings which is not present in the previous file
# Only load the two columns:
# UNITID - This column is the unique identity for each college and will be used to join with the previous file
# MD_EARN_WNE_P10  - This column has the median earnings
df2 = pd.read_csv("https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-Scorecard-Elements.csv", skipinitialspace = True, usecols = ['UNITID','MD_EARN_WNE_P10'])

# %%
# <5>
#Join the two files together to produce a third file which contain all the columns and all colleges that are common to both files
df3 = pd.merge(df,df2, on=['UNITID'])
df3 = df3.dropna()
df3 = df3.reset_index(drop=True)
df3 = df3[df3.MD_EARN_WNE_P10 != 'PrivacySuppressed']

# %%
# <6>
# Explore the new file - number of colleges, head/tail/sample etc.
df3.head(11)
# Out:
#     UNITID                               INSTNM        CITY STABBR  \
# 0   100654             Alabama A & M University      Normal     AL
# 1   100663  University of Alabama at Birmingham  Birmingham     AL
# 2   100706  University of Alabama in Huntsville  Huntsville     AL
# 3   100724             Alabama State University  Montgomery     AL
# 4   100751            The University of Alabama  Tuscaloosa     AL
# 5   100830      Auburn University at Montgomery  Montgomery     AL
# 6   100858                    Auburn University      Auburn     AL
# 7   100937          Birmingham Southern College  Birmingham     AL
# 8   101189                  Faulkner University  Montgomery     AL
# 9   101365        Herzing University-Birmingham  Birmingham     AL
# 10  101435                   Huntingdon College  Montgomery     AL
#
#            ZIP  ADM_RATE     UGDS  TUITIONFEE_IN MD_EARN_WNE_P10
# 0        35762    0.9027   4824.0         9857.0           31000
# 1   35294-0110    0.9181  12866.0         8328.0           41200
# 2        35899    0.8123   6917.0        10280.0           46700
# 3   36104-0271    0.9787   4189.0        11068.0           27700
# 4   35487-0166    0.5330  32387.0        10780.0           44500
# 5   36117-3596    0.8254   4211.0         8020.0           33300
# 6        36849    0.8393  23391.0        10968.0           48800
# 7        35254    0.6186   1283.0        35804.0           46700
# 8   36109-3390    0.5101   2272.0        20970.0           35400
# 9        35209    0.7570    537.0        13850.0           37800
# 10  36106-2148    0.5598   1099.0        26400.0           39900

# %%
df3.tail(11)
# Out:
#       UNITID                               INSTNM            CITY STABBR  \
# 1775  482574                DeVry University-Ohio        Columbus     OH
# 1776  482583            DeVry University-Oklahoma   Oklahoma City     OK
# 1777  482608        DeVry University-Pennsylvania  Ft. Washington     PA
# 1778  482617           DeVry University-Tennessee       Nashville     TN
# 1779  482635               DeVry University-Texas          Irving     TX
# 1780  482653            DeVry University-Virginia       Arlington     VA
# 1781  482680          University of North Georgia       Dahlonega     GA
# 1782  483124     Arizona State University-Skysong      Scottsdale     AZ
# 1783  484473         University of Florida-Online     Gainesville     FL
# 1784  484905  University of North Texas at Dallas          Dallas     TX
# 1785  485272          West Coast University-Miami           Doral     FL
#
#              ZIP  ADM_RATE     UGDS  TUITIONFEE_IN MD_EARN_WNE_P10
# 1775       43209    0.9583    870.0        17476.0           44100
# 1776       73116    1.0000      4.0        17732.0           44100
# 1777       19034    1.0000    338.0        17572.0           44100
# 1778       37211    1.0000     67.0        17828.0           44100
# 1779       75063    0.9333    564.0        17540.0           44100
# 1780       22202    0.7000    227.0        17572.0           44100
# 1781       30597    0.7807  17067.0         4421.0           41900
# 1782       85257    0.6342  24244.0         9222.0           47700
# 1783       32611    0.6802   2735.0         3876.0           56000
# 1784       75241    0.7397   2663.0         7848.0           45000
# 1785  33178-2431    1.0000    687.0        21331.0           54900

# %%
df3.sample(11)
# Out:
#       UNITID                                             INSTNM  \
# 327   146825                                  MacMurray College
# 1373  219949                              Cumberland University
# 845   189097                                    Barnard College
# 225   136774                 Ringling College of Art and Design
# 1076  201821  The Christ College of Nursing and Health Sciences
# 1473  230047                    Brigham Young University-Hawaii
# 1409  223472                      Vet Tech Institute of Houston
# 236   138293                    Webber International University
# 505   160755                     Tulane University of Louisiana
# 1503  232043                       Eastern Mennonite University
# 1204  212197                              Elizabethtown College
#
#                CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 327    Jacksonville     IL  62650-2590    0.5971   521.0        26100.0
# 1373        Lebanon     TN       37087    0.5408  1658.0        21810.0
# 845        New York     NY  10027-6598    0.1542  2540.0        52662.0
# 225        Sarasota     FL  34234-5895    0.6391  1454.0        44560.0
# 1076     Cincinnati     OH  45219-2989    0.5144   912.0        16477.0
# 1473           Laie     HI  96762-1294    0.3677  2855.0         5400.0
# 1409        Houston     TX       77027    0.5758   191.0        14640.0
# 236     Babson Park     FL  33827-0096    0.4923   625.0        25358.0
# 505     New Orleans     LA  70118-5698    0.2150  7871.0        52960.0
# 1503   Harrisonburg     VA  22802-2462    0.5373  1089.0        35800.0
# 1204  Elizabethtown     PA  17022-2298    0.7402  1647.0        45350.0
#
#      MD_EARN_WNE_P10
# 327            36200
# 1373           38700
# 845            57900
# 225            33200
# 1076           56200
# 1473           42200
# 1409           30100
# 236            37200
# 505            61700
# 1503           40300
# 1204           51300

# %%
# <7>
# Find out the top 100 colleges that are hardest to get in (Top 100) from this new file
HardestSchool = df3.loc[df3['ADM_RATE']>0.0000].sort_values('ADM_RATE').head(100).reset_index(drop=True)
HardestSchool
# Out:
#     UNITID                                       INSTNM        CITY STABBR  \
# 0   243744                          Stanford University    Stanford     CA
# 1   166027                           Harvard University   Cambridge     MA
# 2   192110                         The Juilliard School    New York     NY
# 3   186131                         Princeton University   Princeton     NJ
# 4   190150  Columbia University in the City of New York    New York     NY
# ..     ...                                          ...         ...    ...
# 95  213385                            Lafayette College      Easton     PA
# 96  159382        Louisiana State University-Alexandria  Alexandria     LA
# 97  211291                          Bucknell University   Lewisburg     PA
# 98  221254                     O'More College of Design    Franklin     TN
# 99  140720                                Paine College     Augusta     GA
#
#            ZIP  ADM_RATE    UGDS  TUITIONFEE_IN MD_EARN_WNE_P10
# 0        94305    0.0473  7056.0        49617.0           94000
# 1        02138    0.0516  7532.0        48949.0           89700
# 2   10023-6588    0.0592   486.0        43170.0           32800
# 3   08544-0070    0.0641  5246.0        47140.0           74700
# 4        10027    0.0661  8170.0        57208.0           83300
# ..         ...       ...     ...            ...             ...
# 95  18042-1768    0.3081  2567.0        51600.0           68600
# 96  71302-9121    0.3107  2662.0         6668.0           33700
# 97       17837    0.3108  3588.0        53986.0           70800
# 98       37064    0.3146   148.0        29880.0           31800
# 99  30901-3182    0.3180   357.0        14226.0           28200
#
# [100 rows x 9 columns]

# %%
# <8>
# Display the summary statistics of the in-state tuitions of the top 100 colleges that are hardest to get in
HardestSchool.TUITIONFEE_IN.describe()
# Out:
# count      100.000000
# mean     37579.700000
# std      18368.610418
# min       1020.000000
# 25%      16918.250000
# 50%      49640.500000
# 75%      52666.000000
# max      57208.000000
# Name: TUITIONFEE_IN, dtype: float64

# %%
# <9>
# Display the histogram of the in-state tuitions of the top 100 colleges that are hardest to get in
TuitionFeeInstate = HardestSchool['TUITIONFEE_IN']
plt.figure(figsize=(8,5))
plt.hist([TuitionFeeInstate],edgecolor='black')
plt.xlabel("Tuition Range")
plt.ylabel("Number of schools")
plt.title("Instate Tuition Fee")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# <10>
# Display the summary statistics of the earning potentials of the top 100 colleges that are hardest to get in
HardestSchool.MD_EARN_WNE_P10.describe()
# Out:
# count       100
# unique       94
# top       63800
# freq          2
# Name: MD_EARN_WNE_P10, dtype: object

# %%
# <11>
# Display the histogram of the earning potentials of the top 100 colleges that are hardest to get in
plt.hist(HardestSchool.MD_EARN_WNE_P10,edgecolor='black')
plt.title("Histogram of School cost")
plt.xlabel("Cost per year")
plt.ylabel("The number of schools")
plt.show()

# %%
##### <12>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Pandas
HardestSchool.dtypes
HardestSchool['MD_EARN_WNE_P10'] = HardestSchool.MD_EARN_WNE_P10.astype('float64')
scatplot = HardestSchool.plot.scatter(x='TUITIONFEE_IN',y='MD_EARN_WNE_P10',title='Scatterplot of School Tuition Count')

# %%
# <13>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Matplotlib
plt.title('Scatter Plot of Tuition fees and Income')
plt.scatter(x='TUITIONFEE_IN',y='MD_EARN_WNE_P10',data=HardestSchool,c='green',
            edgecolor='black',linewidth=1,alpha=0.72)
plt.xlabel("Tuition Fee")
plt.ylabel("Income")
# Out:
# Text(0, 0.5, 'Income')

# %%
# <14>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Seaborn
import seaborn as sns

sns.set_style('white')
sns.set_style('ticks')

sns.regplot(x='TUITIONFEE_IN', y='MD_EARN_WNE_P10', data=HardestSchool)

# %% [markdown]
# # Your observation/conclusion of the scatter plot (use the following Markdown cell)
#
# From doing this assignment and checking out the data from a plot stand point I see that there is a large enough gap or separation between the schools that are more expensive then others. From look at the data from a plot stand point I can tell a few things one being that the fewer the amount of school that is able to get into a college the more expensive that college is. I also see that with going to an expensive school you have the chance to make are large sum of money when leaving/graduating.
