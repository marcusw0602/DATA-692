# %% [markdown]
# # Assignment #03
# 1. Explore College Scorecard website - https://collegescorecard.ed.gov/
#
# 2. Explore College Scorecard Data web page - https://collegescorecard.ed.gov/data/
#
# 3. Download and skim the documentation - https://collegescorecard.ed.gov/assets/FullDataDocumentation.pdf
#
# 4. Download the dataset - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip (265MB Zip File)
#
# 5. Unzip the file into a folder (there are many files, one for each school year)
#
# 6. Import the 2017-2018 school year file "MERGED2017_18_PP.csv" and explore:
#
#     * how many colleges or rows?
#
#     * how many variables or columns?
#
#     * Look at the first 20 rows
#
#     * look at the last 20 rows
#
#     * Look at a random sample of 20 rows
#
# 7. Since there are too many variables to explore, many of which are not interesting. Modify your import statement to only import the following 9 variables:
#
# - UNITID
# - INSTNM
# - CITY
# - STABBR
# - ZIP
# - ADM_RATE
# - UGDS
# - TUITIONFEE_IN
# - MN_EARN_WNE_P10
#
# 8. Download and read the data dictionary file - https://collegescorecard.ed.gov/assets/CollegeScorecardDataDictionary.xlsx
#
# Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook so that the readers will not need to repeat what you have done to know the meaning of these variables.
#
# 9. Use the predefined cells below to conduct and document your data exploration.
#
# When in doubt, Google. Find examples and read documents/tutorials.
#
# Have fun!

# %%
# Import libraries

import csv
import pandas as pd

# %%
# load the 2017-2018 school year file "MERGED2017_18_PP.csv"  

College = pd.read_csv("MERGED2017_18_PP.csv")
College = College[['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10']]
College['MN_EARN_WNE_P10'].fillna(0, inplace = True) 
College = College.dropna(how='any')

# %%
# Find out how many colleges or rows?  

count = 0
for index, row in College.iterrows():
    count = count + 1
print("Your dataset contains ",count," rows")
# Find out how many variables or columns? 
print("Your dataset contians ",len(College.columns)," columns")
# Out:
# Your dataset contains  1870  rows
# Your dataset contians  9  columns

# %%
# Look at the first 20 rows 

College.head(20)
# Out:
#     UNITID                               INSTNM          CITY STABBR  \
# 0   100654             Alabama A & M University        Normal     AL
# 1   100663  University of Alabama at Birmingham    Birmingham     AL
# 3   100706  University of Alabama in Huntsville    Huntsville     AL
# 4   100724             Alabama State University    Montgomery     AL
# 5   100751            The University of Alabama    Tuscaloosa     AL
# 8   100830      Auburn University at Montgomery    Montgomery     AL
# 9   100858                    Auburn University        Auburn     AL
# 10  100937          Birmingham Southern College    Birmingham     AL
# 16  101189                  Faulkner University    Montgomery     AL
# 22  101365        Herzing University-Birmingham    Birmingham     AL
# 23  101435                   Huntingdon College    Montgomery     AL
# 24  101453        Heritage Christian University      Florence     AL
# 27  101480        Jacksonville State University  Jacksonville     AL
# ...

# %%
# Look at the last 20 rows 

College.tail(20)
# Out:
#       UNITID                                  INSTNM             CITY STABBR  \
# 6475  487524                       Husson University           Bangor     ME
# 6482  487658    Academy of Interactive Entertainment        Lafayette     LA
# 6484  487746                   Yeshiva Zichron Aryeh     Far Rockaway     NY
# 6531  488305        Elim Bible Institute and College             Lima     NY
# 6532  488314             Beth Medrash of Asbury Park         Lakewood     NJ
# 6535  488350          Yeshiva Gedolah Shaarei Shmuel         Lakewood     NJ
# 6571  489344   Chamberlain University-North Carolina        Charlotte     NC
# 6572  489353       Chamberlain University-California   Rancho Cordova     CA
# 6584  489937       Piedmont International University    Winston-Salem     NC
# 6587  490054                 Health Career Institute  West Palm Beach     FL
# 6588  490063              Southern States University        San Diego     CA
# ...

# %%
# Look at a random sample of 20 rows

College.sample(20)
# Out:
#       UNITID                                        INSTNM             CITY  \
# 2549  199209               North Carolina Wesleyan College      Rocky Mount
# 127   106397                        University of Arkansas     Fayetteville
# 833   139931                   Georgia Southern University       Statesboro
# 1478  163268       University of Maryland-Baltimore County        Baltimore
# 1110  151333                     Indiana University-Kokomo           Kokomo
# 3573  229780                    Wayland Baptist University        Plainview
# 1505  164368            Hult International Business School        Cambridge
# 3794  237330                            Concord University           Athens
# 1281  155937                              Sterling College         Sterling
# 4344  384254                                Beacon College         Leesburg
# 3301  219790                          Bryan College-Dayton           Dayton
# ...

# %% [markdown]
# Read (with naked eyes, not computer) the dictionary and find out the definitions of the following 12 columns and copy the text next to the column name
# - UNITID: This name is short for the unit ID for the institution
# - INSTNM: The name is short for Institution name of the school
# - CITY: This is for the city name that the school is located in
# - ZIP: The schools zip code of where specifically it is located at
# - ADM_RATE: The rate of admissions from the school
# - UGDS: The number of undergraduate students that the schools has enrolled
# - TUITIONFEE_IN: This is the name for the tuition fee for in-state schools
# - MN_EARN_WNE_P10: This is the mean income earnings of students thats working not in school for 10 years after entry

# %%
# reimport the data with above 12 columns (ignore all other variables)
College = pd.read_csv("MERGED2017_18_PP.csv", skipinitialspace = True, usecols = ['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10'])

# %%
# Find out the 10 colleges that are hardest to get in (top 10)
College1 = College.loc[College['ADM_RATE']>0.0000]
Hardest=College1.sort_values('ADM_RATE')
Hardest.head(n=10)
# Out:
#       UNITID                                       INSTNM          CITY  \
# 2978  211893                    Curtis Institute of Music  Philadelphia
# 3979  243744                          Stanford University      Stanford
# 1557  166027                           Harvard University     Cambridge
# 2302  192110                         The Juilliard School      New York
# 2123  186131                         Princeton University     Princeton
# 2233  190150  Columbia University in the City of New York      New York
# 633   130794                              Yale University     New Haven
# 1575  166683        Massachusetts Institute of Technology     Cambridge
# 212   110404           California Institute of Technology      Pasadena
# 427   121345                               Pomona College     Claremont
#
#      STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 2978     PA       19103    0.0330   131.0         2675.0              0.0
# ...

# %%
# 10. Find out the average in-state tuition of top 10

print("The average in-state tuition of the top 10 hardest schools to get into is:",TOP_10_College['TUITIONFEE_IN'].mean())

# %% [markdown]
# # Find out the average earnings of graduates from the top 10
#
# There wasnt any data under the column MN_EARN_WNE_P10 to find out the average of earnings

# %%
# Find out the 10 colleges that are easiest to get in (bottom 10)
easiest=College.sort_values('ADM_RATE')
TOP_10_Easy_College = easiest.tail(n=10)
easiest.tail(n=10)

# %%
# Find out the average in-state tuition of the bottom 10

print("The average in-state tuition of the top 10 easiest schools to get into is:",TOP_10_Easy_College['TUITIONFEE_IN'].mean())

# %% [markdown]
# # Find out the average earnings of graduates from the top 10
#
# There wasnt any data under the column MN_EARN_WNE_P10 to find out the average of earnings
